# %%
import pickle

pickle.dump(new_df, open('movies.pkl','wb'))
pickle.dump(similarity, open('similarity.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pickle
# ----> 3 pickle.dump(new_df, open('movies.pkl','wb'))
#       4 pickle.dump(similarity, open('similarity.pkl','wb'))
#
# NameError: name 'new_df' is not defined

# %%
# tags bana chuke ho
new_df = movies[['movie_id','title','tags']].copy()

new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
new_df['tags'] = new_df['tags'].apply(lambda x: x.lower())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # tags bana chuke ho
# ----> 2 new_df = movies[['movie_id','title','tags']].copy()
#       4 new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
#       5 new_df['tags'] = new_df['tags'].apply(lambda x: x.lower())
#
# NameError: name 'movies' is not defined
